# %% [markdown]
# # 01 — Data Exploration
#
# This notebook is for exploring raw data sources.
#
# ## TODO
# - Load sample data from `data/raw/`
# - Examine schema, data types, and distributions
# - Identify quality issues
# - Document findings

# %%
# TODO: Import libraries and load sample data
# import pandas as pd
